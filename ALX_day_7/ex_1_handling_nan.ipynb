# %% [markdown]
# ## Exercise 1
# Calculate the number of scored and lost goals per season for the team of your preference.
#
# - pick the team, for example 'Wisła Kraków'
# - we need to filter the DataFrame to have only matches with this team - either 'Wisła Kraków' will be in home_team or in away_team column. - Once we filter the dataframe we should do the copy to a new dataframe by using .copy().
# - I need to know the number of goals for 'Wisła Kraków' - this information can be found in either home_team_goal or awayt_team_goal
# - apply the function on the whole DataFrame, in exactly same way as we did that for series.

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/MuhammetBilgic/Numpy_Excercises/main/ALX_day_7/matches.csv'
matches = pd.read_csv(url, parse_dates=['date'])
matches
# Out:
#            country                    league                home_team  \
# 0          Belgium    Belgium Jupiler League                 KRC Genk
# 1          Belgium    Belgium Jupiler League         SV Zulte-Waregem
# 2          Belgium    Belgium Jupiler League        KSV Cercle Brugge
# 3          Belgium    Belgium Jupiler League                 KAA Gent
# 4          Belgium    Belgium Jupiler League            FCV Dender EH
# ...            ...                       ...                      ...
# 25974  Switzerland  Switzerland Super League            FC St. Gallen
# 25975  Switzerland  Switzerland Super League                 FC Vaduz
# 25976  Switzerland  Switzerland Super League  Grasshopper Club Zürich
# 25977  Switzerland  Switzerland Super League                   Lugano
# 25978  Switzerland  Switzerland Super League           BSC Young Boys
#
#                away_team       date     season  home_team_goal  away_team_goal
# ...

# %%
team = 'Arsenal'
team_matches = matches[(matches.home_team == team) | (matches.away_team == team)].copy()
team_matches
# Out:
#       country                  league       home_team             away_team  \
# 1729  England  England Premier League         Arsenal  West Bromwich Albion
# 1739  England  England Premier League         Arsenal     Tottenham Hotspur
# 1756  England  England Premier League      Stoke City               Arsenal
# 1758  England  England Premier League         Arsenal     Manchester United
# 1769  England  England Premier League         Arsenal           Aston Villa
# ...       ...                     ...             ...                   ...
# 4718  England  England Premier League         Arsenal            Stoke City
# 4730  England  England Premier League         Chelsea               Arsenal
# 4738  England  England Premier League  Leicester City               Arsenal
# 4748  England  England Premier League         Arsenal     Manchester United
# 4766  England  England Premier League         Watford               Arsenal
#
# ...

# %% [markdown]
# axis=0 - by columns
#
# axis=1 - by rows
#
# https://stackoverflow.com/questions/25773245/ambiguity-in-pandas-dataframe-numpy-array-axis-definition/25774395#25774395

# %%
def team_goals(row):
    if row.home_team == team:
        return row.home_team_goal
    else:
        return row.away_team_goal

team_matches['team_goals'] = team_matches.apply(team_goals, axis=1)
team_matches
# Out:
#       country                  league       home_team             away_team  \
# 1729  England  England Premier League         Arsenal  West Bromwich Albion
# 1739  England  England Premier League         Arsenal     Tottenham Hotspur
# 1756  England  England Premier League      Stoke City               Arsenal
# 1758  England  England Premier League         Arsenal     Manchester United
# 1769  England  England Premier League         Arsenal           Aston Villa
# ...       ...                     ...             ...                   ...
# 4718  England  England Premier League         Arsenal            Stoke City
# 4730  England  England Premier League         Chelsea               Arsenal
# 4738  England  England Premier League  Leicester City               Arsenal
# 4748  England  England Premier League         Arsenal     Manchester United
# 4766  England  England Premier League         Watford               Arsenal
#
# ...
